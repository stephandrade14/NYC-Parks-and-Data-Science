# %% [markdown]
# # Predictive Analysis - Parks and Arrests

# %% [markdown]
# #### Elise Chessman

# %% [markdown]
# After exploring the census data, park data, and NYPD arrest data, it appears as if there is not much of a relationship between parks and the type of arrests that occur. Next, we will focus on if demographic factors of the neigbhorhoods where the arrests occur that are also close to parks might influence if the model predicts arrests. First I'll bring in my dataframe of arrests from the NYPD for all of 2021, with a boolean column of whether or not those arrests occurred within 100m of a park.

# %%
import pandas as pd
import geopandas as gpd
import requests
import json

# %% [markdown]
# This is the same arrests dataset, but with a boolean column of if the arrest occurred within 100m of a park.

# %%
parkarrests = pd.read_pickle('../NYCParks-SAEC/parkarrests.pandas')

parkarrests = gpd.GeoDataFrame(parkarrests, 
                        geometry = gpd.points_from_xy(
                         parkarrests.longitude, 
                         parkarrests.latitude, crs='EPSG:4326'))
pd.set_option('display.max_columns', None)

parkarrests = parkarrests.rename(columns={'index_right':'old'})
parkarrests.head(2)
# Out:
#   arrest_key              arrest_date pd_cd pd_desc  ky_cd ofns_desc  \
# 0  238013474  2021-12-18T00:00:00.000   157  RAPE 1  104.0      RAPE
# 8  233697123  2021-09-17T00:00:00.000   157  RAPE 1  104.0      RAPE
#
#      law_code law_cat_cd arrest_boro arrest_precinct jurisdiction_code  \
# 0  PL 1303501          F           Q             105                97
# 8  PL 1303501          F           Q             105                 0
#
#   age_group perp_sex perp_race x_coord_cd y_coord_cd           latitude  \
# 0     18-24        M     BLACK    1057636     203954  40.72618713000002
# 8     25-44        M     BLACK    1057636     203954  40.72618713000002
#
#             longitude                                    geocoded_column  \
# 0  -73.73523390399998  {'type': 'Point', 'coordinates': [-73.73523390...
# 8  -73.73523390399998  {'type': 'Point', 'coordinates': [-73.73523390...
#
#   :@computed_region_f5dn_yrer :@computed_region_yeji_bk3q  \
# ...

# %% [markdown]
# ## Bringing in the Census Data

# %% [markdown]
# This is all copied over from Steph's notebook working on the census data.

# %%
r = requests.get('https://api.census.gov/data/2015/acs/acs5?get=NAME,B01001_001E,B01001H_001E&for=county:*&for=tract:*&in=state:36')
print(r.text)

censusdata = r.json()

# Turn JSON into a pandas dataframe
df = pd.DataFrame(censusdata[1:], columns=censusdata[0])
df.head()
# Out:
# [["NAME","B01001_001E","B01001H_001E","state","county"],
# ["Schoharie County, New York","31913","29868","36","095"],
# ["Fulton County, New York","54606","50960","36","035"],
# ["Rensselaer County, New York","159900","135285","36","083"],
# ["Franklin County, New York","51280","41999","36","033"],
# ["Queens County, New York","2301139","601381","36","081"],
# ["Washington County, New York","62700","58182","36","115"],
# ["New York County, New York","1629507","767701","36","061"],
# ["Cayuga County, New York","79173","71808","36","011"],
# ["Rockland County, New York","320688","204596","36","087"],
# ["Niagara County, New York","214150","185219","36","063"],
# ["Essex County, New York","38912","35886","36","031"],
# ["Nassau County, New York","1354612","851645","36","059"],
# ["Jefferson County, New York","118947","98419","36","045"],
# ["Suffolk County, New York","1501373","1045354","36","103"],
# ["Wyoming County, New York","41446","37232","36","121"],
# ...

# %%
# Renaming the column to be more specfic
df.rename(columns = {'B01001_001E':'Population','B01001H_001E':'NonHispanicWhite'}, inplace=True)
df
# Out:
#                             NAME Population NonHispanicWhite state county
# 0     Schoharie County, New York      31913            29868    36    095
# 1        Fulton County, New York      54606            50960    36    035
# 2    Rensselaer County, New York     159900           135285    36    083
# 3      Franklin County, New York      51280            41999    36    033
# 4        Queens County, New York    2301139           601381    36    081
# ..                           ...        ...              ...   ...    ...
# 57  Cattaraugus County, New York      78962            71985    36    009
# 58      Madison County, New York      72427            67735    36    053
# 59  Schenectady County, New York     154796           116261    36    093
# 60      Genesee County, New York      59458            54029    36    037
# 61        Yates County, New York      25187            24063    36    123
#
# [62 rows x 5 columns]

# %%
# Create a new column that will give us the perentage of nonhispanic white individuals in New York State.
df['prc_NonHispanicWhite'] = df.NonHispanicWhite.astype(float) / df.Population.astype(float) * 100 
df.head(20)
# Out:
#                            NAME Population NonHispanicWhite state county  \
# 0    Schoharie County, New York      31913            29868    36    095
# 1       Fulton County, New York      54606            50960    36    035
# 2   Rensselaer County, New York     159900           135285    36    083
# 3     Franklin County, New York      51280            41999    36    033
# 4       Queens County, New York    2301139           601381    36    081
# 5   Washington County, New York      62700            58182    36    115
# 6     New York County, New York    1629507           767701    36    061
# 7       Cayuga County, New York      79173            71808    36    011
# 8     Rockland County, New York     320688           204596    36    087
# 9      Niagara County, New York     214150           185219    36    063
# 10       Essex County, New York      38912            35886    36    031
# 11      Nassau County, New York    1354612           851645    36    059
# ...

# %%
def get_nhWhite(countyFIPS):
    r = requests.get('https://api.census.gov/data/2019/acs/acs5?get=NAME,B01001_001E,B01001H_001E&for=tract:*&in=state:36%20county:{}'.format(countyFIPS))
    censusdata = r.json()
    df = pd.DataFrame(censusdata[1:], columns=censusdata[0])
    df['prc_NonHispanicWhite'] = df.B01001H_001E.astype(float) / df.B01001_001E.astype(float) * 100

    return df

# %%
queens_county = get_nhWhite('081')
queens_county
# Out:
#                                           NAME B01001_001E B01001H_001E state  \
# 0    Census Tract 361, Queens County, New York        2238           73    36
# 1    Census Tract 363, Queens County, New York        1771           66    36
# 2    Census Tract 371, Queens County, New York        1335           19    36
# 3    Census Tract 377, Queens County, New York        3620           17    36
# 4    Census Tract 379, Queens County, New York        6851           63    36
# ..                                         ...         ...          ...   ...
# 664  Census Tract 660, Queens County, New York        3318          122    36
# 665  Census Tract 683, Queens County, New York        3970          458    36
# 666  Census Tract 716, Queens County, New York           0            0    36
# 667  Census Tract 240, Queens County, New York        6826          149    36
# 668  Census Tract 246, Queens County, New York           0            0    36
#
# ...

# %%
ny_county = get_nhWhite('061')
ny_county
# Out:
#                                               NAME B01001_001E B01001H_001E  \
# 0      Census Tract 255, New York County, New York        5999         1602
# 1      Census Tract 222, New York County, New York        3369         1084
# 2    Census Tract 10.01, New York County, New York        1546         1075
# 3        Census Tract 7, New York County, New York        8501         6212
# 4      Census Tract 103, New York County, New York        2065         1252
# ..                                             ...         ...          ...
# 283    Census Tract 218, New York County, New York        6236         1280
# 284    Census Tract 283, New York County, New York        7949         1537
# 285    Census Tract 291, New York County, New York       12165          769
# 286    Census Tract 295, New York County, New York        8182         2848
# 287      Census Tract 9, New York County, New York        1796         1144
#
#     state county   tract  prc_NonHispanicWhite
# ...

# %%
race_Df = gpd.read_file('/users/EliseChessman 1/Documents/Github/NYCParks-SAEC/data/acs2020_5yr_B03002_14000US36047081800.geojson')
race_Df
# Out:
#                    geoid                               name  B03002001  \
# 0     14000US36005000100          Census Tract 1, Bronx, NY     6600.0
# 1     14000US36005000200          Census Tract 2, Bronx, NY     4167.0
# 2     14000US36005000400          Census Tract 4, Bronx, NY     5684.0
# 3     14000US36005001600         Census Tract 16, Bronx, NY     5917.0
# 4     14000US36005001901      Census Tract 19.01, Bronx, NY     1910.0
# ...                  ...                                ...        ...
# 2322  14000US36085030302  Census Tract 303.02, Richmond, NY     6569.0
# 2323  14000US36085031901  Census Tract 319.01, Richmond, NY     3293.0
# 2324  14000US36085031902  Census Tract 319.02, Richmond, NY     4953.0
# 2325  14000US36085032300     Census Tract 323, Richmond, NY     1200.0
# 2326  14000US36085990100    Census Tract 9901, Richmond, NY        0.0
#
#       B03002001, Error  B03002002  B03002002, Error  B03002003  \
# ...

# %%
keep_race_Df = ['geoid',
 'name',
 'B03002001',
 'B03002002',
 'B03002003',
 'B03002004',
 'B03002005',
 'B03002006',
 'B03002007',
 'B03002008',
 'B03002009',
 'B03002010',
 'B03002011',
 'B03002012',
 'B03002013',
 'B03002014',
 'B03002015',
 'B03002016',
 'B03002017',
 'B03002018',
 'B03002019',
 'B03002020',
 'B03002021',
 'geometry']

# %%
race_Df = race_Df[keep_race_Df ]

# %%
race_Df.columns = ['geoid', 'name','Total',
                   'Not Hispanic', 
                   'White',
                   'Black',
                   'American Indian and Alaska Native',
                   'Asian',
                   'Pacific Islander',
                   'Other Race',
                   'Two or more races',
                   'Two or more races including other race',
                   'Three or more races',
                   'Hispanic',
                   'Hispanic White',
                   'Hispanic Black',
                   'Hispanic American Indian and Alaska Native',
                   'Hispanic Asian',
                   'Hispanic Pacific Islander',
                   'Hispanic Other Race',
                   'Hispanic Two or more races',
                   'Hispanic Two or more races including other race',
                   'Hispanic Three or more races','geometry']

# %%
list(race_Df)
# Out:
# ['geoid',
#  'name',
#  'Total',
#  'Not Hispanic',
#  'White',
#  'Black',
#  'American Indian and Alaska Native',
#  'Asian',
#  'Pacific Islander',
#  'Other Race',
#  'Two or more races',
#  'Two or more races including other race',
#  'Three or more races',
#  'Hispanic',
#  'Hispanic White',
#  'Hispanic Black',
#  'Hispanic American Indian and Alaska Native',
#  'Hispanic Asian',
#  'Hispanic Pacific Islander',
#  'Hispanic Other Race',
#  'Hispanic Two or more races',
#  'Hispanic Two or more races including other race',
#  'Hispanic Three or more races',
#  'geometry']

# %%
keep_race_Df2 = ['geoid',
 'name',
 'Total',
 'White',
 'Black',
 'American Indian and Alaska Native',
 'Asian',
 'Pacific Islander',
 'Other Race',
 'Two or more races',
 'Hispanic',
 'geometry']

# %%
race_Df = race_Df[keep_race_Df2]

# %%
race_Df
# Out:
#                    geoid                               name   Total   White  \
# 0     14000US36005000100          Census Tract 1, Bronx, NY  6600.0   817.0
# 1     14000US36005000200          Census Tract 2, Bronx, NY  4167.0    77.0
# 2     14000US36005000400          Census Tract 4, Bronx, NY  5684.0   371.0
# 3     14000US36005001600         Census Tract 16, Bronx, NY  5917.0   229.0
# 4     14000US36005001901      Census Tract 19.01, Bronx, NY  1910.0   259.0
# ...                  ...                                ...     ...     ...
# 2322  14000US36085030302  Census Tract 303.02, Richmond, NY  6569.0  1732.0
# 2323  14000US36085031901  Census Tract 319.01, Richmond, NY  3293.0   311.0
# 2324  14000US36085031902  Census Tract 319.02, Richmond, NY  4953.0   498.0
# 2325  14000US36085032300     Census Tract 323, Richmond, NY  1200.0   135.0
# 2326  14000US36085990100    Census Tract 9901, Richmond, NY     0.0     0.0
#
# ...

# %%
race_Df['Percent White'] = race_Df['White']/race_Df['Total']*100

race_Df['Percent Black'] = race_Df['Black']/race_Df['Total']*100

race_Df['Percent American Indian and Alaska Native'] = race_Df['American Indian and Alaska Native']/race_Df['Total']*100

race_Df['Percent Asian'] = race_Df['Asian']/race_Df['Total']*100

race_Df['Percent Pacific Islander'] = race_Df['Pacific Islander']/race_Df['Total']*100

race_Df['Percent Other Race'] = race_Df['Other Race']/race_Df['Total']*100

race_Df['Percent Two or more races'] = race_Df['Two or more races']/race_Df['Total']*100

race_Df['Percent Hispanic'] = race_Df['Hispanic']/race_Df['Total']*100

# %%
race_Df.head(5)
# Out:
#                 geoid                           name   Total  White   Black  \
# 0  14000US36005000100      Census Tract 1, Bronx, NY  6600.0  817.0  3234.0
# 1  14000US36005000200      Census Tract 2, Bronx, NY  4167.0   77.0   980.0
# 2  14000US36005000400      Census Tract 4, Bronx, NY  5684.0  371.0   965.0
# 3  14000US36005001600     Census Tract 16, Bronx, NY  5917.0  229.0  1986.0
# 4  14000US36005001901  Census Tract 19.01, Bronx, NY  1910.0  259.0   610.0
#
#    American Indian and Alaska Native  Asian  Pacific Islander  Other Race  \
# 0                               27.0  171.0               0.0         0.0
# 1                                0.0  115.0               0.0        52.0
# 2                                0.0   87.0               0.0         2.0
# 3                              192.0   63.0               0.0        55.0
# 4                                0.0    0.0               0.0         0.0
#
#    Two or more races  Hispanic  \
# ...

# %%
race_Df.plot(figsize=(12,12),
                 column='Percent White',
                  cmap='plasma',
                 legend=True, 
                 scheme='equal_interval')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Spatial Joining Census and Arrest Data

# %%
#parkarrests = parkarrests.reset_index

# %%
parkarrests.to_crs('EPSG:4326', inplace=True)
race_Df.to_crs('EPSG:4326', inplace=True)

# %%
allgdf = gpd.sjoin(race_Df, parkarrests, how='left', predicate='intersects')

# %%
allgdf
# Out:
#                    geoid                             name   Total  White  \
# 0     14000US36005000100        Census Tract 1, Bronx, NY  6600.0  817.0
# 0     14000US36005000100        Census Tract 1, Bronx, NY  6600.0  817.0
# 0     14000US36005000100        Census Tract 1, Bronx, NY  6600.0  817.0
# 0     14000US36005000100        Census Tract 1, Bronx, NY  6600.0  817.0
# 0     14000US36005000100        Census Tract 1, Bronx, NY  6600.0  817.0
# ...                  ...                              ...     ...    ...
# 2325  14000US36085032300   Census Tract 323, Richmond, NY  1200.0  135.0
# 2325  14000US36085032300   Census Tract 323, Richmond, NY  1200.0  135.0
# 2325  14000US36085032300   Census Tract 323, Richmond, NY  1200.0  135.0
# 2325  14000US36085032300   Census Tract 323, Richmond, NY  1200.0  135.0
# 2326  14000US36085990100  Census Tract 9901, Richmond, NY     0.0    0.0
#
#        Black  American Indian and Alaska Native  Asian  Pacific Islander  \
# ...
